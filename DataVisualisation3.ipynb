# %%
#Data Visualization III
#Download	the	Iris	flower	dataset	or	any	other	dataset	into	a	DataFrame.	(e.g., https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:
#Listdown the features and their types(e.g., numeric,nominal)available in the dataset.
#Create a histogram for each feature in the data set to illustrate the feature distributions.
#3. Create a boxplot for each feature in the dataset.
#Compare distributions and identify outliers.

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset('iris')
df.columns=['c1','c2' ,'c3' ,'c4','c5' ]

df.head()
# Out:
#     c1   c2   c3   c4      c5
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
df.describe()
# Out:
#                c1          c2          c3          c4
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   c1      150 non-null    float64
#  1   c2      150 non-null    float64
#  2   c3      150 non-null    float64
#  3   c4      150 non-null    float64
#  4   c5      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.columns
# Out:
# Index(['c1', 'c2', 'c3', 'c4', 'c5'], dtype='object')

# %%
sns.displot(x='c1',data=df,hue='c5')

# %%
import matplotlib.pyplot as plt

df.hist(bins=20, figsize=(10,8))
plt.suptitle("Histogram of Iris Features")
plt.show()
#case 2. Histogram (Feature Distribution)
#Histogram for Each Feature
#Explanation
#A histogram shows how values are distributed.  Helps understand: Range  , Frequency , Skewness

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.boxplot(data=df)
plt.title("Boxplot of Iris Features")
plt.show()

#case 3- Interpretation -Points outside whiskers = Outliers
#Petal features usually have fewer outliers
#Sepal width may show some extreme values

# %%
# Boxplot grouped by species
sns.boxplot(x='c5', y='c2', data=df)
plt.title("Sepal Width by Species")
plt.show()

#Petal Length & Width Clearly separate species → very important features
#Sepal Length-Moderate overlap
#Sepal Width-Most variation + some outliers
#Outliers-Visible in sepal width,--Very few in petal features

# %%
#observations or insights or inference of above graph
#c1 is evenly distributed
#c2 is normally distributed
#c3 is left squed distribution

# %%
#Iris dataset contains 150 samples and 5 features
#There are 4 numeric and 1 categorical feature
#Histograms show data distribution and spread
#Boxplots reveal median, variation, and outliers
#Petal features help in better classification
#Sepal width shows maximum variation and outliers

# %%
sns.displot(x='c1',data=df,hue='c5')

# %%
sns.displot(x='c1',data=df)

#Inference:

 #   In the histogram for sepal length, we observe that the distribution is somewhat normal with a peak around 5.8 cm.
 #   Most of the iris flowers have a sepal length ranging from approximately 4.5 cm to 7.0 cm.
  #  There are relatively fewer flowers with extremely short or long sepal lengths, as evidenced by the lower frequencies at the tails of the distribution

# %%
sns.histplot(x='c2',data=df)

#Inference:
#    The histogram for sepal width shows a roughly normal distribution, albeit with some variation.
 #   The most common sepal width appears to be around 3.0 cm.
  #  There is a noticeable spread in sepal widths, ranging from approximately 2.0 cm to 4.5 cm. However,
  #there's a slight skew towards higher sepal widths, as indicated by the slightly longer right tail of the distribution.
  #Inference: Shows th distribution of the sepal_width of the iris flowers. COunt for sepal width 3.0 is highest. The has a little bit of skewnwss
# Out:
# <Axes: xlabel='c2', ylabel='Count'>

# %%
sns.histplot(x='c3',data=df)

#Inference:

 #   Data is not normally distributed
  #  Some of the petal length are ranging from 1-2
   # Most data is in range of 3-7


   #Data is not normally distributed
#Some of the petal length are ranging from 0-0.5
#Most data is in range of 1.0-2.5
# Out:
# <Axes: xlabel='c3', ylabel='Count'>
