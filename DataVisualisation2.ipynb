# %%
#Data Visualization II
#Use the inbuilt dataset 'titanic' as used in the above problem.
#Plot a box plot for distribution of age with respect to each gender along with the information about whether they survived or not. (Column names : 'sex' and 'age')
#Write observations on the inference from the above statistics.


import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

dataset = sns.load_dataset('titanic')

dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.scatterplot(data=dataset,x='age',y='fare')
#scatter plot to check outliers in data
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.boxplot(x='sex', y='age', data=dataset)
plt.title('Distribution of Age by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()
#Observation For Distribution of Age by GenderMales:The median age of males is around 29, suggesting that half of the males onboard are youngerthan 29,
#and the other half are older.The spread of ages (IQR) is ranging from ~19 (Q1) to ~39 (Q3).
#There are outliers above 65, that indicates a few elderly males.
#Females:
#The median age for females is around 28, suggesting that half of the females onboard areyounger than 28, and the other half are older.
#The IQR spans from ~18 (Q1) to ~38 (Q3).There are no significant outliers in the age distribution for females.

#inference- INFERENCE

 #   Minimum age is 0
  #  25th-50th percentile people are of age from 20-30
   # 50th-75th percentile people are of age from 30-40
    #above 75th percentile people are of age abve 40
    #With hue we can also check the age group of people survived and not survived

# %%
sns.boxplot(x='sex', y='age', data=dataset, hue="survived")
#plt.title('Distribution of Age by Gender and Survial Status')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#The median age is around 28, slightly lower than the non-survived groupThe IQR (18 to 35) shows a younger age range among surviving males compared
#to non-surviving males.
#Fewer outliers compared to the non-survived group, suggesting that only few elderly peoplesurvivedFemales:Not Survived:Median age is around 25,
#suggesting that half of the females that didn't survive were youngerthan 25 and the other half were older.
#The IQR for female age 18 to 32 indicating most females of this age group didn't survived.

#The IQR also defines that majority of non-surviving female were adultsThere are no visible outliers indicating that all the females having age above 60 and onboardhave survived.
#Survived:Median age is slightly higher (~30) indicating that slightly older females survived.The IQR (20 to 40) is broader than that of non-surviving females,
#indicating that most femalesof this age survived


#Inference:Survival seems to favor females slightly, especially for older women.Male survivors have slightly
#younger medians compared to non-survivors which indicatescomparatively more younger males survivedFemale survivors have slightly older medians compared to
#non-survivors which indicates thatmore number of older women survived.Outliers are primarily seen among males (mostly non-survivors)
#suggesting elderly males wereless likely to survive.Distribution of Males vary greatly in age compared to females due to a broader IQR andlonger whiskers.


#Inference: In above chart ,in addition to the information about the age of each gender,
#you can also see the distribution of the passengers who survived. For instance, you can see that among the male passengers, on average more younger people survived as compared to the older ones.

# %%
#Boxplot for Distribution of Fare by Passenger Class and SurvivalStatus
plt.title('Distribution of Fare by Passenger Class and Survival Status')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
sns.boxplot(x='pclass', y='fare', data=dataset, hue='survived')
# Out:
# <Axes: title={'center': 'Distribution of Fare by Passenger Class and Survival Status'}, xlabel='Passenger Class', ylabel='Fare'>

# %%
#Observation for Distribution of Fare by Passenger Class andSurvival StatusFirst-Class Passengers (Class 1):

#Survivors:The median fare for survivors is significantly higher compared to non-survivors.
#Most survivors paid fares within a high range (approximately 150–300), with several extremeoutliers above 400.

#A large proportion of first-class survivors indicates that paying a higher fare might have beenassociated with a higher likelihood of survival.
#Non-Survivors:The median fare for non-survivors is lower than for survivors.
#This suggests that even within first class, survival may have been influenced by
#additionalfactors like cabin location or social status.

#Second-Class Passengers (Class 2):Survivors:The median fare for survivors is slightly higher than that of non-survivors.
#The IQR of survivors spans a broader range, indicating that passengers paying higher fares insecond class had a better chance of survival.
#Non-Survivors:The median fare is relatively low compared to survivors.Most non-survivors paid fares clustered below 50.

#Third-Class Passengers (Class 3):Survivors:The median fare for survivors is slightly higher than that of non-survivors, but the overall farerange for both groups overlaps significantly.
#Survivors in third class generally paid fares between 10 and 20, with very few paying higherfares.
#Despite lower fares, some third-class passengers survived, likely influenced by other factorslike proximity to lifeboats or priority during evacuation.

#Non-Survivors:The median fare is the lowest across all classes, and most non-survivors paid fares clusterednear 10.A large proportion of third-class passengers did not survive,
 #suggesting that class played asignificant role in survival.

 #Inference:Higher fares were associated with higher survival rates,
 #especially in first and second classes.This suggests that passengers who could afford higher-class accommodations had betteraccess to lifeboats and priority rescue efforts.
 #First-class passengers had the highest survival rates, followed by second-class and third-classpassengers. Economic stratification strongly influenced survival chances.

 #Third-class passengers had the lowest survival rates despite paying similar fares.
#This could bedue to their cabins being located in lower decks, further from lifeboats, or limited access torescue opportunities.

# %%
#Violin Plot-  The Violin Plot The violin plot is similar to the box plot, however, the violin plot allows us to display all the components
#that actually correspond to the data point.

#The violinplot() function is used to plot the violin plot. Like the box plot, the first parameter is the categorical column,
#the second parameter is the numeric column while the third parameter is the dataset.
sns.violinplot(x='sex',y='age',data=dataset, hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex',y='age',hue= 'survived',data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex',y='age',hue= 'survived',split = True,data=dataset)

#Inference: For instance, if you look at the bottom of the violin plot for the males who survived (left-orange),
#you can see that it is thicker than the bottom of the violin plot for the males who didn't survive (left-blue).

#This means that the number of young male passengers who survived is greater than the number of young male passengers who did not survive.
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex',y='age',data=dataset, hue='sex')
#Strip plot plots the data points in the form of strip, with which we can observe the density of the range.
# Out:
# <Axes: xlabel='sex', ylabel='age'>
